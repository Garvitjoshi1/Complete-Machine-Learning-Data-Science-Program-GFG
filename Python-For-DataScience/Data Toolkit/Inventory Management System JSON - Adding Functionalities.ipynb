# %%
import json

fd = open('Records.json','r')
js = fd.read()
fd.close()

record = json.loads(js)

print("====================MENU=====================")
for key in record.keys():
    print(key,'|', record[key]['Name'], '|',record[key]['Price'],'|', record[key]['Qn'])
print("=============================================")
print('')

ui_pr = str(input("Enter product ID : "))
ui_qn = int(input("Enter Quantity   : "))

print("=============================================")
print('')

if (record[ui_pr]['Qn'] >= ui_qn):
    
    record[ui_pr]['Qn'] = record[ui_pr]['Qn'] - ui_qn
    print("Name      : ", record[ui_pr]["Name"])
    print("Price (Rs): ", record[ui_pr]["Price"])
    print("Quantity  : ", record[ui_pr]['Qn'])
    print("=============================================")
    print("Billing   : ", record[ui_pr]['Qn'] * record[ui_pr]["Price"], "Rs")
    print("=============================================")

else:
    print("Sorry, We are not having enough Quantity in out Inventory")
    print("We are only having ", record[ui_pr]['Qn'], "items")
    print("Would you like to take them ?")
    
    user = str(input("Enter Y/N ? "))
    if user == 'Y' or user == 'y':
        
        print("Name      : ", record[ui_pr]["Name"])
        print("Price (Rs): ", record[ui_pr]["Price"])
        print("Quantity  : ", record[ui_pr]['Qn'])
        print("=============================================")
        print("Billing   : ", record[ui_pr]['Qn'] * record[ui_pr]["Price"], "Rs")

        record[ui_pr]['Qn'] = 0
    
    else:
        print("Thanks!, Visit Again")
js = json.dumps(record)

fd = open('Records.json','w')
fd.write(js)
fd.close()

print('')
print("=============================================")
print("  Thanks for your order, Inventory Updated!  ")
print("==============================================")
# Out:
# ====================MENU=====================
# 1001 | 5 Star | 10 | 200
# 1002 | Bar_One | 20 | 200
# 1003 | Candy | 2 | 1000
# 1004 | Chocalate Cake | 550 | 20
# 1005 | Blueberries Cake | 650 | 10
# ...
#
# Enter product ID : 1001
# Enter Quantity   : 201
# ...
#
# Sorry, We are not having enough Quantity in out Inventory
# We are only having  200 items
# Would you like to take them ?
# Enter Y/N ? y
# Name      :  5 Star
# Price (Rs):  10
# Quantity  :  200
# ...
# Billing   :  2000 Rs
#
# ...
#   Thanks for your order, Inventory Updated!
# ...
