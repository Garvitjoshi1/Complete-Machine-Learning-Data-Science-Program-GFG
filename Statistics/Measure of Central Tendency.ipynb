# %%
import pandas as pd
import numpy as np
import seaborn as sns # seaborn is imported because it has in-built data.
import statistics

# %%
data = [1, 1, 1, 2, 3, 4, 4, 4, 4, 5, 6, 7, 7, 7, 8]

# %%
statistics.mean(data)
# Out:
# 4.266666666666667

# %%
df = sns.load_dataset('mpg')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
statistics.mean(df['mpg'])
# Out:
# 23.514572864321607

# %%
statistics.mean(df['cylinders'])
# Out:
# 5.454773869346734

# %%
df.mean
# Out:
# <bound method DataFrame.mean of       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
data = [1, 1, 1, 2, 3, 4, 4, 4, 4, 5, 6, 7, 7, 7, 8, 50]
# outlier added to data as 50.

# %%
statistics.mean(data)
# this made a drastic change in mean making it to 7.125
# so here we use median to find real value.
# Out:
# 7.125

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
statistics.median(data)
# comparing to the data we considered firstly, have the same mean as th median of now.
# Out:
# 4.0

# %%
df.median
# Out:
# <bound method DataFrame.median of       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
statistics.mode(data)
# Out:
# 4

# %%
df.mode()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  13.0        4.0          97.0       150.0    1985          14.5
# 1   NaN        NaN           NaN         NaN    2130           NaN
#
#    model_year origin        name
# 0        73.0    usa  ford pinto
# 1         NaN    NaN         NaN

# %%
len(df[df['weight'] == 1985])
# Out:
# 4
