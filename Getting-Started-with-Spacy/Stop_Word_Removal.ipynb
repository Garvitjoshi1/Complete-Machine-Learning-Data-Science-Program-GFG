# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# `` "en_core_web_sm" is an English language multi-task Convolutional Neural Network(CNN) trained on OntoNotes. Assigns context-specific token vectors, POS tags, dependency parse, and named entities.``

# %%
text = "Data science, a multidisciplinary field drawing from statistics, computer science, and mathematics, utilizes specialized programming and algorithms to extract meaningful insights from vast amounts of data. By analyzing structured and unstructured data, data scientists uncover hidden patterns and trends, enabling organizations to make informed decisions, optimize operations, and predict future outcomes. This field plays a crucial role in various sectors, from healthcare and finance to marketing and cybersecurity, driving innovation and progress through the power of data analysis."

# %% [markdown]
# #### How is en_core_web_sm different from en_core_web_lg ?
# `` The difference is in the accuracy of the predictions. But, as you can see in the comparison in the spaCy documentation, the difference is very small. The en_core_web_lg (788 MB) compared to en_core_web_sm (10 MB): LAS: 90.07% vs 89.66% ``

# %%
nlp.Defaults.stop_words
# these are stop words
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
len(nlp.Defaults.stop_words)
# 326 are total number of stop words present in this model.
# Out:
# 326

# %%
nlp.vocab['is'].is_stop
# to check in nlp loaded model whether the word given in vocab function is a stop word or not.
# Out:
# True
